# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Entity_Linking/Code_RunTeminal/EntityLinking/code
# Out:
# /content/drive/.shortcut-targets-by-id/1Rw0jAWNHvvQA25aFewsx8Rkrp2ihpw9z/Code_RunTeminal/EntityLinking/code

# %%
# !python -W ignore train.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 100% 7813/7813 [2:06:48<00:00,  1.03it/s]
# 100% 782/782 [06:22<00:00,  2.04it/s]
# 100% 196/196 [00:04<00:00, 43.08it/s]
# Epoch:  0
# Loss train = 285318.42803382874, Loss valid = 24558.01171875, Loss test = 212.42970275878906
# Accuracy train = 0.80004201778753, Accuracy valid = 0.845448890271267, Accuracy test = 0.6275510204081632
# 100% 7813/7813 [2:06:52<00:00,  1.03it/s]
# 100% 782/782 [06:20<00:00,  2.05it/s]
# 100% 196/196 [00:04<00:00, 45.31it/s]
# Epoch:  1
# Loss train = 241337.31670188904, Loss valid = 22537.953125, Loss test = 206.5103302001953
# Accuracy train = 0.8479145060297748, Accuracy valid = 0.8681322343427162, Accuracy test = 0.6224489795918368
# 100% 7813/7813 [2:05:44<00:00,  1.04it/s]
#  63% 490/782 [03:54<02:14,  2.17it/s]
